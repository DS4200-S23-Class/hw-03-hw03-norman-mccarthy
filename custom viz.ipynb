# %%
import pandas as pd

# %%
data = pd.read_csv('rotten_tomatoes_top_movies.csv')

# %%
data = data[['critic_score', 'people_score', 'type']]

# %%
data
# Out:
#       critic_score  people_score                type
# 0               96          79.0  Action & Adventure
# 1               94          90.0  Action & Adventure
# 2               97          88.0  Action & Adventure
# 3               97          86.0  Action & Adventure
# 4               97          93.0  Action & Adventure
# ...            ...           ...                 ...
# 1605            15          46.0             Western
# 1606            16          49.0             Western
# 1607            14          68.0             Western
# 1608            12          20.0             Western
# 1609             2          29.0             Western
#
# [1610 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = data['critic_score']
y = data['people_score']
groups = data.groupby('type')
for name, group in groups:
    plt.rcParams['figure.facecolor'] = 'white'
    plt.plot(group.critic_score, group.people_score, marker='o', linestyle='', markersize=5, label=name)
ax = plt.subplot(111)
# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
# Put a legend to the right of the current axis
ax.legend(title='Genre type', loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Critic Scores vs People Scores')
plt.xlabel('Critic Score')
plt.ylabel('People score')
ax.set_facecolor('xkcd:white')
plt.show()
